# %%
# importing a database from  kaggle
import pandas as pd
import numpy as np

vgs_dF = pd.read_csv(r"C:\Users\38095\Documents\GitHub\vgsales.csv")

# %%
vgs_dF
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
print(vgs_dF.head())

print(vgs_dF.info())

print(vgs_dF.describe())
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ...

# %%
missing_game = vgs_dF['Name'].isnull().any()
missing_film = vgs_dF['Year'].isnull().any()
missing_publisher = vgs_dF['Publisher'].isnull().any()

zeros_game = (vgs_dF['Name'] == 0).any()
zeros_film = (vgs_dF['Year'] == 0).any()
zeros_publisher = (vgs_dF['Publisher'] == 0).any()

# Вывод результатов
print("Empty 'Name':", missing_game)
print("Null 'Name':", zeros_game)
print("Empty 'Year':", missing_film)
print("Null 'Year':", zeros_film)
print("Empty 'Publisher':", missing_publisher)
print("Null 'Publisher':", zeros_publisher)
# Out:
# Empty 'Name': False
# Null 'Name': False
# Empty 'Year': True
# Null 'Year': False
# Empty 'Publisher': True
# Null 'Publisher': False

# %%
vgs_dF.replace([np.inf, -np.inf], np.nan, inplace=True)
vgs_dF['Year'].fillna(0, inplace=True)
vgs_dF['Year'] = vgs_dF['Year'].astype(int)
# Out:
#         Rank                                              Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 1          2                                 Super Mario Bros.      NES  1985
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# ...      ...                                               ...      ...   ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
# ...

# %%
columns_with_null = vgs_dF.columns[vgs_dF.isnull().any()]
print(columns_with_null)
for column in columns_with_null:
    null_values_column = vgs_dF[column].isnull().sum()
   

null_counts = vgs_dF.isnull().sum()
print(null_counts)
# Out:
# Index(['Publisher'], dtype='object')
# Rank             0
# Name             0
# Platform         0
# Year             0
# Genre            0
# Publisher       58
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# Global_Sales     0
# dtype: int64

# %%
for column in vgs_dF:
    duplicates = vgs_dF[column].duplicated().sum()
    print(f"duplicates in {column} {duplicates} ")
# Out:
# duplicates in Rank 0
# duplicates in Name 5105
# duplicates in Platform 16567
# duplicates in Year 16558
# duplicates in Genre 16586
# duplicates in Publisher 16019
# duplicates in NA_Sales 16189
# duplicates in EU_Sales 16293
# duplicates in JP_Sales 16354
# duplicates in Other_Sales 16441
# duplicates in Global_Sales 15975

# %%
counts_game = vgs_dF['Name'].value_counts()
duplicates_game = counts_game[counts_game > 1]
print(duplicates_game)
# Out:
# Name
# Need for Speed: Most Wanted    12
# Ratatouille                     9
# FIFA 14                         9
# LEGO Marvel Super Heroes        9
# Madden NFL 07                   9
#                                ..
# Triple Play 2002                2
# FIFA Soccer                     2
# EA Playground                   2
# Dragon's Dogma                  2
# Stuntman                        2
# Name: count, Length: 2775, dtype: int64

# %%
vgs_dF.drop_duplicates(inplace=True)

# %%
counts_game = vgs_dF['Name'].value_counts()
duplicates_game = counts_game[counts_game > 1]
print(duplicates_game)
# Out:
# Name
# Need for Speed: Most Wanted    12
# Ratatouille                     9
# FIFA 14                         9
# LEGO Marvel Super Heroes        9
# Madden NFL 07                   9
#                                ..
# Triple Play 2002                2
# FIFA Soccer                     2
# EA Playground                   2
# Dragon's Dogma                  2
# Stuntman                        2
# Name: count, Length: 2775, dtype: int64

# %%
mg_df = pd.read_csv(r"C:\Users\38095\Documents\GitHub\movies - games1 (1).csv", encoding='latin1')

# %%
mg_df
# Out:
#                                        Game  Year                   Developer  \
# 0                        3 Ninjas Kick Back  1994          Malibu Interactive
# 1                      007: Licence to Kill  1989                      Quixel
# 2                               007 Legends  2012                     Eurocom
# 3     102 Dalmatians: Puppies to the Rescue  2000            Crystal Dynamics
# 4                                       NaN   NaN                         NaN
# ...                                     ...   ...                         ...
# 999                                  Willow  1989                      Capcom
# 1000                       The Wizard of Oz  1993         Manley & Associates
# 1001                The World Is Not Enough  2000                     Eurocom
# 1002                The World Is Not Enough  2000     Black Ops Entertainment
# 1003               The World of Cars Online  2008  Disney Interactive Studios
#
# ...

# %%
columns_with_null = mg_df.columns[mg_df.isnull().any()]
print(columns_with_null)
for column in columns_with_null:
    null_values_column = mg_df[column].isnull().sum()
   

null_counts = mg_df.isnull().sum()
print(null_counts)
# Out:
# Index(['Game', 'Year', 'Developer', 'Publisher', 'Film'], dtype='object')
# Game         410
# Year         410
# Developer    130
# Publisher    243
# Film         410
# dtype: int64

# %%
mg_df.dropna(subset=['Game','Film'], inplace=True)
mg_df.drop_duplicates(subset=['Game','Film'], inplace=True)

# %%
mg_df
# Out:
#                                        Game  Year                   Developer  \
# 0                        3 Ninjas Kick Back  1994          Malibu Interactive
# 1                      007: Licence to Kill  1989                      Quixel
# 2                               007 Legends  2012                     Eurocom
# 3     102 Dalmatians: Puppies to the Rescue  2000            Crystal Dynamics
# 5                       300: March to Glory  2007           Collision Studios
# ...                                     ...   ...                         ...
# 996      Wild Wild West: The Steel Assassin  1999       SouthPeak Interactive
# 997                                  Willow  1988           Brian A. Rice Inc
# 1000                       The Wizard of Oz  1993         Manley & Associates
# 1001                The World Is Not Enough  2000                     Eurocom
# 1003               The World of Cars Online  2008  Disney Interactive Studios
#
# ...

# %%
mg_df.shape
# Out:
# (542, 5)

# %%
columns_with_null = mg_df.columns[mg_df.isnull().any()]
print(columns_with_null)
for column in columns_with_null:
    null_values_column = mg_df[column].isnull().sum()
   

null_counts = mg_df.isnull().sum()
print(null_counts)
# Out:
# Index(['Developer', 'Publisher'], dtype='object')
# Game          0
# Year          0
# Developer    15
# Publisher    18
# Film          0
# dtype: int64

# %%
for column in mg_df:
    duplicates = mg_df[column].duplicated().sum()
    print(f"duplicates in {column} {duplicates} ")
# Out:
# duplicates in Game 10
# duplicates in Year 499
# duplicates in Developer 157
# duplicates in Publisher 303
# duplicates in Film 86

# %%
mg_df['Game'].duplicated()
mg_df['Film'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 5       False
#         ...
# 996     False
# 997     False
# 1000    False
# 1001    False
# 1003    False
# Name: Film, Length: 542, dtype: bool

# %%
mg_df['Game'].value_counts()
mg_df['Film'].value_counts()
# Out:
# Film
# Top Gun                           9
# Shrek                             7
# Jurassic Park III                 7
# Aliens                            6
# Lord of the Rings film trilogy    4
#                                  ..
# Garfield Gets Real                1
# Frozen                            1
# From Dusk till Dawn               1
# Flushed Away                      1
# Cars film series                  1
# Name: count, Length: 456, dtype: int64

# %%
counts_game = mg_df['Game'].value_counts()
duplicates_game = counts_game[counts_game > 1]
print(duplicates_game)

counts_film = mg_df['Film'].value_counts()
duplicates_film = counts_film[counts_film > 1]
print(duplicates_film)
# Out:
# Game
# The Movie                           3
# Bill & Ted's Excellent Adventure    2
# Ghostbusters                        2
# Beverly Hills Cop                   2
# Mad Max                             2
# The Godfather                       2
# RoboCop                             2
# The Italian Job                     2
# Jurassic Park                       2
# Name: count, dtype: int64
# Film
# Top Gun                                          9
# Shrek                                            7
# Jurassic Park III                                7
# Aliens                                           6
# Lord of the Rings film trilogy                   4
# Scarface                                         3
# Madagascar                                       3
# Indiana Jones and the Last Crusade               3
# Antz                                             3
# Cars                                             3
# Transformers                                     3
# ...

# %%
# Определение дубликатов для столбца 'Game'
duplicates_game = mg_df[mg_df['Game'].duplicated(keep=False)]

# Определение дубликатов для столбца 'Film'
duplicates_film = mg_df[mg_df['Film'].duplicated(keep=False)]

# Объединение дубликатов
all_duplicates = pd.concat([duplicates_game, duplicates_film])

# Вывод всех дубликатов
all_duplicates
# Out:
#                                  Game  Year  \
# 128                 Beverly Hills Cop  2006
# 129                 Beverly Hills Cop  1990
# 132  Bill & Ted's Excellent Adventure  1989
# 133  Bill & Ted's Excellent Adventure  1991
# 344                      Ghostbusters  1984
# ..                                ...   ...
# 938            Transformers: The Game  2007
# 973                          WarGames  1984
# 974                WarGames: Defcon 1  1998
# 977                      The Warriors  2005
# 978        The Warriors: Street Brawl  2009
#
#                                  Developer                        Publisher  \
# 128            Atomic Planet Entertainment              Blast Entertainment
# 129                               Tynesoft                              NaN
# 132            Off The Wall Productions[4]                         Capstone
# 133  Mev Dinc, Focus (as Software Studios)         Electric Dreams Software
# ...

# %%
# Проверка наличия незаполненных ячеек в столбце 'Game'
missing_game = mg_df['Game'].isnull().any()

# Проверка наличия нулевых значений в столбце 'Game'
zeros_game = (mg_df['Game'] == 0).any()

# Проверка наличия незаполненных ячеек в столбце 'Film'
missing_film = mg_df['Film'].isnull().any()

# Проверка наличия нулевых значений в столбце 'Film'
zeros_film = (mg_df['Film'] == 0).any()

# Вывод результатов
print("Empty 'Game':", missing_game)
print("Null 'Game':", zeros_game)
print("Empty 'Film':", missing_film)
print("Null 'Film':", zeros_film)
# Out:
# Empty 'Game': False
# Null 'Game': False
# Empty 'Film': False
# Null 'Film': False

# %%
mg_df.dtypes
# Out:
# Game         object
# Year         object
# Developer    object
# Publisher    object
# Film         object
# dtype: object

# %%
mg_df = mg_df[mg_df['Year'] != '(cancelled)']

# %%
mg_df['Year'] = mg_df['Year'].astype(int)
# Out:
# C:\Users\38095\AppData\Local\Temp\ipykernel_27712\1094734758.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mg_df['Year'] = mg_df['Year'].astype(int)

# %%
mg_df.dtypes
# Out:
# Game         object
# Year          int32
# Developer    object
# Publisher    object
# Film         object
# dtype: object

# %%
mg_df
# Out:
#                                        Game  Year                   Developer  \
# 0                        3 Ninjas Kick Back  1994          Malibu Interactive
# 1                      007: Licence to Kill  1989                      Quixel
# 2                               007 Legends  2012                     Eurocom
# 3     102 Dalmatians: Puppies to the Rescue  2000            Crystal Dynamics
# 5                       300: March to Glory  2007           Collision Studios
# ...                                     ...   ...                         ...
# 996      Wild Wild West: The Steel Assassin  1999       SouthPeak Interactive
# 997                                  Willow  1988           Brian A. Rice Inc
# 1000                       The Wizard of Oz  1993         Manley & Associates
# 1001                The World Is Not Enough  2000                     Eurocom
# 1003               The World of Cars Online  2008  Disney Interactive Studios
#
# ...

# %%
for column in mg_df:
    print (mg_df[column].value_counts())
# Out:
# Game
# The Movie                           3
# Ghostbusters                        2
# Beverly Hills Cop                   2
# The Godfather                       2
# Bill & Ted's Excellent Adventure    2
#                                    ..
# Fantastic Four                      1
# Fantasia: Music Evolved             1
# Fantasia                            1
# The Evil Dead                       1
# The World of Cars Online            1
# Name: count, Length: 531, dtype: int64
# Year
# 2007    30
# 2009    29
# 2006    27
# 1994    24
# 2005    24
# 2004    23
# 2001    23
# 2002    23
# 2010    23
# 2008    22
# 1990    20
# 1991    16
# 2011    16
# 1995    16
# 1997    15
# 2000    14
# 2003    14
# 1996    14
# 1992    14
# 1986    12
# 1999    12
# 2012    11
# 1993    11
# 1987    11
# 1989    11
# 1998    10
# 1983     9
# 2014     8
# 1984     8
# 2013     7
# 1985     7
# 2017     6
# 1982     6
# 1988     6
# 2016     4
# 2015     4
# 2021     3
# 2023     3
# ...

# %%
mg_df.rename(columns={'Game': 'Name'}, inplace=True)
mg_df
# Out:
# C:\Users\38095\AppData\Local\Temp\ipykernel_27712\4253140320.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mg_df.rename(columns={'Game': 'Name'}, inplace=True)
#                                        Name  Year                   Developer  \
# 0                        3 Ninjas Kick Back  1994          Malibu Interactive
# 1                      007: Licence to Kill  1989                      Quixel
# 2                               007 Legends  2012                     Eurocom
# 3     102 Dalmatians: Puppies to the Rescue  2000            Crystal Dynamics
# 5                       300: March to Glory  2007           Collision Studios
# ...                                     ...   ...                         ...
# ...

# %%
vgs_dF.to_csv('vgs_cleanedSL.csv', index=False)
mg_df.to_csv('mg_cleanedSL.csv', index=False)

# %%
vgs_mg_df = pd.merge(mg_df,vgs_dF, on=['Name', 'Year', 'Publisher'], how = 'inner')

# %%
vgs_mg_df
# Out:
#                           Name  Year              Developer  \
# 0                Alien Trilogy  1996    Probe Entertainment
# 1     Aliens: Colonial Marines  2013    Gearbox Software[b]
# 2     Aliens: Colonial Marines  2013    Gearbox Software[b]
# 3     Aliens: Colonial Marines  2013    Gearbox Software[b]
# 4      Alvin and the Chipmunks  2007  Sensory Sweep Studios
# ..                         ...   ...                    ...
# 320    Wanted: Weapons of Fate  2009                   Grin
# 321  Where the Wild Things Are  2009       Griptonite Games
# 322  Where the Wild Things Are  2009       Griptonite Games
# 323  Where the Wild Things Are  2009       Griptonite Games
# 324  Where the Wild Things Are  2009       Griptonite Games
#
#                                   Publisher                       Film   Rank  \
# 0                     Acclaim Entertainment          Alien film series   4150
# 1                                      Sega          Alien film series   2574
# ...

# %%
duplicates = vgs_mg_df[vgs_mg_df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Name, Year, Developer, Publisher, Film, Rank, Platform, Genre, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
vgs_mg_df.rename(columns=lambda x: x.strip().lower().replace(' ', '_'), inplace=True)

# %%
vgs_mg_df.to_csv('vgs_mg_cleanedSL.csv', index=False)

# %%
vgs_mg_df
# Out:
#                           name  year              developer  \
# 0                Alien Trilogy  1996    Probe Entertainment
# 1     Aliens: Colonial Marines  2013    Gearbox Software[b]
# 2     Aliens: Colonial Marines  2013    Gearbox Software[b]
# 3     Aliens: Colonial Marines  2013    Gearbox Software[b]
# 4      Alvin and the Chipmunks  2007  Sensory Sweep Studios
# ..                         ...   ...                    ...
# 320    Wanted: Weapons of Fate  2009                   Grin
# 321  Where the Wild Things Are  2009       Griptonite Games
# 322  Where the Wild Things Are  2009       Griptonite Games
# 323  Where the Wild Things Are  2009       Griptonite Games
# 324  Where the Wild Things Are  2009       Griptonite Games
#
#                                   publisher                       film   rank  \
# 0                     Acclaim Entertainment          Alien film series   4150
# 1                                      Sega          Alien film series   2574
# ...
